# %% [markdown]
# ### GBLT and Neural-Tree Examples

# %% [markdown]
# #### Load and prepared data

# %%
import numpy as np
import pandas as pd
from modeva import DataSet
# Loading data into pandas dataframe
df = pd.read_csv("credit_default.csv")
df.columns = ["employment",	"income", "dti", "score", "amount", 
              "tenure",	"emp_length", "delinquencies",
              "savings", "utilization", "default"]

# %%
# Create dataset object holder
ds = DataSet()
ds.load_dataframe(data = df)

# %%
## Preprocess the data
ds.encode_categorical(method="ordinal")
ds.scale_numerical(features=tuple(ds.feature_names_numerical), method="standardize") # standardized numerical features
ds.set_target('default')
ds.preprocess()
## Split data into training and testing sets randomly
ds.set_random_split()

# %% [markdown]
# #### GBLT Training

# %%
N_TREES = 4 # number of trees in boosting
# For classification tasks
from modeva.models import MoGLMTreeBoostClassifier
model_gblt = MoGLMTreeBoostClassifier(name = "GBLT", max_depth=1, n_estimators=N_TREES)
# train model with input: ds.train_x and target: ds.train_y
model_gblt.fit(ds.train_x, ds.train_y)
# Out:
# MoGLMTreeBoostClassifier(n_estimators=4, name='GBLT')

# %%
# Create a testsuite that bundles dataset and model
from modeva import TestSuite
ts = TestSuite(ds, model_gblt) # store bundle of dataset and model in fs
# View model performance metrics
result = ts.diagnose_accuracy_table()
# display the output
result.table
# Out:
#           AUC     ACC      F1  LogLoss   Brier
# train  0.9153  0.8742  0.6597   0.3113  0.0936
# test   0.9169  0.8755  0.6631   0.3130  0.0926
# GAP    0.0016  0.0012  0.0034   0.0017 -0.0009

# %%
results = ts.interpret_ei()
results.plot(n_bars=10)
# Out:
#             <!DOCTYPE html>
#             <html lang="en" style="height: 100%">
#             <head>
#             <meta charset="utf-8">
#             </head>
#             <body style="height: 100%; margin: 0">
#
#
#                 <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/echarts/5.5.0/echarts.min.js"></script>
#                 <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/echarts-gl/2.0.8/echarts-gl.min.js"></script>
#                 <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/dat-gui/0.7.9/dat.gui.min.js"></script>
#                 <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/echarts-wordcloud@2.1.0/dist/echarts-wordcloud.min.js"></script>
#
#             <div id="1751572713.69349380.8623" style="height: 600px; width: 600px; overflow: auto"></div>
#
#             <script type="text/javascript">
#             var dom = document.getElementById('1751572713.69349380.8623');
#             dom.innerHTML = ""
#             dom.setAttribute('_echarts_instance_', '')
#             var myChart = echarts.init(dom, null, {
#                 renderer: 'canvas',
#                 useDirtyRect: false
#                 });
#             var app = {};
#
#             var option;
#     option = {"chart_id": "1751572713.69349380.8623", "link_id": null, "figname": "", "title": {"show": true, "text": "Effect Importance", "link": "", "target": "blank", "textStyle": {"fontStyle": "normal", "fontWeight": "bolder", "fontFamily": "sans-serif", "fontSize": 15, "textBorderType": "solid", "textShadowColor": "transparent", "overflow": "none", "ellipsis": "..."}, "subtext": "", "sublink": "", "subtarget": "blank", "textAlign": "center", "textVerticalAlign": "auto", "padding": 0, "itemGap": 10, "z": 2, "left": "50.0%", "top": "5%", "right": "auto", "bottom": "auto", "backgroundColor": "transparent", "borderColor": "#ccc", "changed_name_key": {"id_": "id"}}, "grid": {"show": true, "width": "auto", "height": "auto", "z": 2, "left": "5%", "top": "10%", "right": "10%", "bottom": "5%", "borderColor": "#ccc", "borderWidth": 1, "containLabel": true, "backgroundColor": "transparent", "changed_name_key": {"id_": "id"}}, "legend": null, "brush": null, "yAxis": [{"show": true, "data": ["income & score", "employment & score", "emp_length", "employment", "score & emp_length", "dti", "utilization", "score & utilization", "dti & score", "score"], "type": "category", "position": "bottom", "name": "", "nameLocation": "center", "nameTextStyle": {"color": "#747475", "fontStyle": "normal", "fontWeight": "normal", "fontFamily": "sans-serif", "fontSize": 12, "backgroundColor": "", "borderType": "solid", "shadowColor": "transparent", "textBorderType": "solid", "textShadowColor": "transparent", "overflow": "none", "ellipsis": "..."}, "nameGap": "auto", "splitNumber": 5, "logBase": 10, "axisLine": {}, "axisTick": {"show": true, "alignWithLabel": "none", "interval": "auto", "length": 5}, "axisLabel": {"show": true, "margin": 8, "showMinLabel": true, "fontStyle": "normal", "fontWeight": "normal", "fontFamily": "sans-serif", "fontSize": 12, "backgroundColor": "transparent", "borderType": "solid", "shadowColor": "transparent", "textBorderType": "solid", "textShadowColor": "transparent", "overflow": "none", "ellipsis": "...", "width": 40.0}, "splitLine": {"show": true, "interval": "auto"}, "splitArea": {"show": false, "interval": "auto"}, "axisPointer": {"show": false}, "dimension": "2d", "ignored": false, "changed_name_key": {"min_": "min", "max_": "max", "type_": "type", "name_": "name"}}], "xAxis": [{"show": true, "type": "value", "position": "bottom", "name": "Importance", "nameLocation": "center", "nameTextStyle": {"color": "#747475", "fontStyle": "normal", "fontWeight": "normal", "fontFamily": "sans-serif", "fontSize": 12, "backgroundColor": "", "borderType": "solid", "shadowColor": "transparent", "textBorderType": "solid", "textShadowColor": "transparent", "overflow": "none", "ellipsis": "..."}, "nameGap": 30, "min": -0.068, "max": 0.75, "splitNumber": 5, "logBase": 10, "axisLine": {}, "axisTick": {"show": true, "alignWithLabel": "none", "interval": "auto", "length": 5}, "axisLabel": {"show": true, "margin": 8, "showMinLabel": false, "showMaxLabel": false, "fontStyle": "normal", "fontWeight": "normal", "fontFamily": "sans-serif", "fontSize": 12, "backgroundColor": "transparent", "borderType": "solid", "shadowColor": "transparent", "textBorderType": "solid", "textShadowColor": "transparent", "overflow": "none", "ellipsis": "...", "width": null}, "splitLine": {"show": true, "interval": "auto"}, "splitArea": {"show": false, "interval": "auto"}, "axisPointer": {"show": false}, "dimension": "2d", "ignored": false, "changed_name_key": {"min_": "min", "max_": "max", "type_": "type", "name_": "name"}}], "parallelAxis": null, "series": [{"type": "bar", "colorBy": "series", "z": 2, "legendHoverLink": true, "stack": "", "stackStrategy": "samesign", "cursor": "pointer", "clip": true, "label": {"show": false, "color": "black", "position": null, "fontSize": 12}, "itemStyle": {}, "seriesLayoutBy": "column", "data": [{"value": [1.265028540596178e-08, "delinquencies"], "itemStyle": {"color": "#1f77b4"}, "visualMap": false}, {"value": [1.4258715301836042e-08 ...

# %%
result = ts.interpret_effects(features="score")
result.plot()
# Out:
#             <!DOCTYPE html>
#             <html lang="en" style="height: 100%">
#             <head>
#             <meta charset="utf-8">
#             </head>
#             <body style="height: 100%; margin: 0">
#
#
#                 <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/echarts/5.5.0/echarts.min.js"></script>
#                 <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/echarts-gl/2.0.8/echarts-gl.min.js"></script>
#                 <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/dat-gui/0.7.9/dat.gui.min.js"></script>
#                 <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/echarts-wordcloud@2.1.0/dist/echarts-wordcloud.min.js"></script>
#
#             <div id="1751572902.27361230.6027" style="height: 600px; width: 600px; overflow: auto"></div>
#
#             <script type="text/javascript">
#             var dom = document.getElementById('1751572902.27361230.6027');
#             dom.innerHTML = ""
#             dom.setAttribute('_echarts_instance_', '')
#             var myChart = echarts.init(dom, null, {
#                 renderer: 'canvas',
#                 useDirtyRect: false
#                 });
#             var app = {};
#
#             var option;
#     option = {"chart_id": "1751572902.27361230.6027", "link_id": null, "figname": "", "title": {"show": true, "text": "score (68.2 %)", "link": "", "target": "blank", "textStyle": {"fontStyle": "normal", "fontWeight": "bolder", "fontFamily": "sans-serif", "fontSize": 15, "textBorderType": "solid", "textShadowColor": "transparent", "overflow": "none", "ellipsis": "..."}, "subtext": "", "sublink": "", "subtarget": "blank", "textAlign": "center", "textVerticalAlign": "auto", "padding": 0, "itemGap": 10, "z": 2, "left": "50.0%", "top": "5%", "right": "auto", "bottom": "auto", "backgroundColor": "transparent", "borderColor": "#ccc", "changed_name_key": {"id_": "id"}}, "grid": {"show": true, "width": "auto", "height": "auto", "z": 2, "left": "5%", "top": "10%", "right": "10%", "bottom": "5%", "borderColor": "#ccc", "borderWidth": 1, "containLabel": true, "backgroundColor": "transparent", "changed_name_key": {"id_": "id"}}, "legend": null, "brush": null, "yAxis": [{"show": true, "data": [-6.624923375291481, -6.5168309066086385, -6.408738437925794, -6.300645969242951, -6.1925535005601064, -6.084461031877264, -5.976368563194419, -5.868276094511578, -5.760183625828733, -5.6520911571458905, -5.543998688463048, -5.435906219780203, -5.327813751097362, -5.219721282414516, -5.1116288137316745, -5.00353634504883, -4.895443876365987, -4.7873514076831425, -4.6792589390003, -4.571166470317459, -4.463074001634612, -4.354981532951771, -4.2468890642689265, -4.138796595586084, -4.030704126903239, -3.9226116582203963, -3.8145191895375534, -3.706426720854709, -3.598334252171866, -3.490241783489023, -3.3821493148061803, -3.2740568461233357, -3.165964377440493, -3.0578719087576482, -2.949779440074807, -2.8416869713919626, -2.7335945027091197, -2.625502034026275, -2.5174095653434323, -2.4093170966605895, -2.301224627977745, -2.193132159294904, -2.0850396906120574, -1.9769472219292163, -1.8688547532463717, -1.760762284563529, -1.652669815880686, -1.5445773471978415, -1.4364848785149986, -1.328392409832154, -1.220299941149313, -1.1122074724664683, -1.0041150037836255, -0.8960225351007827, -0.7879300664179381, -0.6798375977350952, -0.5717451290522515, -0.4636526603694078, -0.35556019168656405, -0.24746772300372122, -0.13937525432087838, -0.03128278563803555, 0.07680968304480817, 0.1849021517276519, 0.2929946204104956, 0.40108708909333846, 0.5091795577761822, 0.6172720264590259, 0.7253644951418696, 0.8334569638247116, 0.9415494325075553, 1.049641901190399, 1.1577343698732419, 1.2658268385560856, 1.3739193072389293, 1.482011775921773, 1.5901042446046159, 1.6981967132874596, 1.8062891819703024, 1.9143816506531453, 2.022474119335989, 2.1305665880188327, 2.2386590567016764, 2.3467515253845193, 2.454843994067363, 2.5629364627502067, 2.6710289314330504, 2.7791214001158924, 2.887213868798736, 2.99530633748158, 3.1033988061644227, 3.2114912748472664, 3.31958374353011, 3.4276762122129534, 3.535768680895797, 3.6438611495786404, 3.751953618261484, 3.8600460869443265, 3.9681385556271698, 4.0762310243100135, 4.184323492992856, 4.292415961675701, 4.400508430358544, 4.5086008990413875, 4.616693367724231, 4.724785836407074, 4.832878305089917, 4.94097077377276, 5.049063242455604, 5.157155711138449, 5.265248179821291, 5.373340648504133, 5.411290183611685, 5.3232483830555575, 5.235206582499428, 5.1471647819432995, 5.059122981387169, 4.971081180831042, 4.883039380274911, 4.794997579718784, 4.706955779162656, 4.618913978606526, 4.530872178050398, 4.442830377494268, 4.35478857693814, 4.26674677638201, 4.178704975825882, 4.090663175269752, 4.002621374713624, 3.914579574157496, 3.8265377736013657, 3.738495973045238, 3.6504541724891078, 3.56241237193298, 3.47437057137685, 3.386328770820722, 3.298286970264592, 3.210245169708464, 3.122203369152336, 3.034161568596206, 2.946119768040078, 2.858077967483948, 2.77003616692782, 2.68199436637169, 2.593952565815562, 2.505910765259432, 2.4178689647033043, 2.329827164147176, 2.2417853635910463, 2.153743563034918, 2.0657017624787883, 1.977659961 ...

# %% [markdown]
# #### Neural Tree Training

# %%
# For classification tasks
from modeva.models import MoNeuralTreeClassifier
model_neut = MoNeuralTreeClassifier(name = "NeuralTree", n_estimators=N_TREES)
# train model with input: ds.train_x and target: ds.train_y
model_neut.fit(ds.train_x, ds.train_y)
# Out:
# MoNeuralTreeClassifier(clip_predict=False, device='cpu',
#                        estimator=MoGLMTreeBoostClassifier(n_estimators=4,
#                                                           name='MoGLMTreeBoostClassifier'),
#                        learning_rate=1.0, max_depth=1, min_impurity_decrease=0,
#                        min_samples_leaf=50, n_epoch_no_change=5, n_estimators=4,
#                        n_feature_search=5, n_screen_grid=1, n_split_grid=20,
#                        name='MoGLMTreeBoostClassifier', reg_lambda=0.1,
#                        simplified=True, split_custom=None)

# %%
ts_neut = TestSuite(ds, model_neut) # store bundle of dataset and model in fs
# View model performance metrics
result = ts_neut.diagnose_accuracy_table()
# display the output
result.table
# Out:
#           AUC     ACC      F1  LogLoss   Brier
# train  0.9156  0.8738  0.6558   0.3108  0.0935
# test   0.9170  0.8765  0.6639   0.3129  0.0926
# GAP    0.0014  0.0027  0.0082   0.0021 -0.0008

# %%
result = ts_neut.interpret_effects(features="score")
result.plot()
# Out:
#             <!DOCTYPE html>
#             <html lang="en" style="height: 100%">
#             <head>
#             <meta charset="utf-8">
#             </head>
#             <body style="height: 100%; margin: 0">
#
#
#                 <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/echarts/5.5.0/echarts.min.js"></script>
#                 <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/echarts-gl/2.0.8/echarts-gl.min.js"></script>
#                 <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/dat-gui/0.7.9/dat.gui.min.js"></script>
#                 <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/echarts-wordcloud@2.1.0/dist/echarts-wordcloud.min.js"></script>
#
#             <div id="1751573021.84182790.8623" style="height: 600px; width: 600px; overflow: auto"></div>
#
#             <script type="text/javascript">
#             var dom = document.getElementById('1751573021.84182790.8623');
#             dom.innerHTML = ""
#             dom.setAttribute('_echarts_instance_', '')
#             var myChart = echarts.init(dom, null, {
#                 renderer: 'canvas',
#                 useDirtyRect: false
#                 });
#             var app = {};
#
#             var option;
#     option = {"chart_id": "1751573021.84182790.8623", "link_id": null, "figname": "", "title": {"show": true, "text": "score (67.3 %)", "link": "", "target": "blank", "textStyle": {"fontStyle": "normal", "fontWeight": "bolder", "fontFamily": "sans-serif", "fontSize": 15, "textBorderType": "solid", "textShadowColor": "transparent", "overflow": "none", "ellipsis": "..."}, "subtext": "", "sublink": "", "subtarget": "blank", "textAlign": "center", "textVerticalAlign": "auto", "padding": 0, "itemGap": 10, "z": 2, "left": "50.0%", "top": "5%", "right": "auto", "bottom": "auto", "backgroundColor": "transparent", "borderColor": "#ccc", "changed_name_key": {"id_": "id"}}, "grid": {"show": true, "width": "auto", "height": "auto", "z": 2, "left": "5%", "top": "10%", "right": "10%", "bottom": "5%", "borderColor": "#ccc", "borderWidth": 1, "containLabel": true, "backgroundColor": "transparent", "changed_name_key": {"id_": "id"}}, "legend": null, "brush": null, "yAxis": [{"show": true, "data": [-6.1342804749362685, -6.04989406268794, -5.967884256787556, -5.88825105723512, -5.810994464030629, -5.736114477174084, -5.663611096665486, -5.593484322504836, -5.5257341546921275, -5.460360593227369, -5.397363638110558, -5.33674328934169, -5.27626747856219, -5.2098153136030225, -5.137036240805639, -5.057930260170034, -4.972497371696214, -4.880737575384174, -4.782650871233918, -4.678237259245446, -4.567496739418752, -4.450429311753844, -4.327034976250714, -4.19731373290937, -4.061265581729805, -3.918890522712025, -3.770188555856025, -3.615159681161808, -3.4538038986293733, -3.28612120825872, -3.112111610049852, -2.932645237026343, -2.7587806941657425, -2.5938725319582394, -2.4379207504038427, -2.290925349502547, -2.152886329254353, -2.0238036896592626, -1.903677430717274, -1.792507552428389, -1.690294054792604, -1.5970369378099236, -1.512736201480344, -1.4373918458038686, -1.3710038707804946, -1.3135722764102231, -1.2650970626930538, -1.225578229628987, -1.195015777218023, -1.1734097054601613, -1.160760014355402, -1.149842391052573, -1.1321744292208964, -1.1077427257337809, -1.0765472805912262, -1.0385880937932326, -0.9938651653397998, -0.942378495230928, -0.8841280834666172, -0.8191139300468673, -0.7473360349716793, -0.6687943982410517, -0.5834890198549846, -0.4914198998134785, -0.3925870381165336, -0.28699043476414954, -0.1746300897563267, -0.05550600309306436, 0.07038182522563674, 0.20303339519977515, 0.3404604147067799, 0.47387179606102847, 0.6022246632809178, 0.7255190163664487, 0.84375485531762, 0.9569321801344322, 1.0650509908168853, 1.1681112873649793, 1.266113069778713, 1.3590563380580887, 1.4469410922031056, 1.5297673322137637, 1.607535058090062, 1.6802442698320017, 1.747894967439582, 1.8104871509128038, 1.8680208202516664, 1.9204959754561686, 1.9679126165263128, 2.010578887510441, 2.0585505775081967, 2.1166827779824886, 2.1849754889333157, 2.263428710360678, 2.3520424422645774, 2.450816684645011, 2.5597514375019803, 2.6788467008354844, 2.808102474645525, 2.9475187589321017, 3.0970955536952136, 3.2568328589348616, 3.426730674651044, 3.6067890008437624, 3.797007837513018, 3.9973871846588085, 4.207927042281131, 4.428627410379993, 4.659488288955389, 4.889806190794257, 5.099139391366822, 5.2869893815463245, 5.4533561613327635, 5.598239730726137, 5.721640089726446, 5.823557238333687, 5.903991176547868, 5.96294190436898, 6.000409421797027, 6.016393728832012, 6.010894825473929, 5.98391271172278, 5.93544738757857, 5.8654988530412915, 5.77406710811095, 5.66115215278754, 5.52675398707107, 5.370872610961529, 5.196355274239977, 5.024798598548729, 4.860676161707952, 4.70398796371765, 4.55473400457782, 4.412914284288466, 4.278528802849584, 4.151577560261176, 4.032060556523241, 3.9199777916357825, 3.8153292655987956, 3.718114978412281, 3.6283349300762424, 3.5459891205906766, 3.4710775499555835, 3.403600218170964, 3.3435571252368206, 3.290948271153148, 3.245773655919951, 3.2080004041742343, 3.1689074562036645, 3.121697506356901, 3.066370554633942, 3.0029266 ...

# %% [markdown]
# #### Imposing Monotonicities

# %%
model_neut_mono = MoNeuralTreeClassifier(name = "NeuralTree-mono", n_estimators=N_TREES, nn_max_epochs = 10, 
                                    feature_names = ds.feature_names, mono_increasing_list = tuple(["utilization", "dti", "delinquencies"]),
                                    mono_decreasing_list = tuple(["score", "income", "savings", "emp_length"]))
# train model with input: ds.train_x and target: ds.train_y
model_neut_mono.fit(ds.train_x, ds.train_y)
# Out:
# MoNeuralTreeClassifier(clip_predict=False, device='cpu',
#                        estimator=MoGLMTreeBoostClassifier(n_estimators=4,
#                                                           name='MoGLMTreeBoostClassifier'),
#                        learning_rate=1.0, max_depth=1, min_impurity_decrease=0,
#                        min_samples_leaf=50, n_epoch_no_change=5, n_estimators=4,
#                        n_feature_search=5, n_screen_grid=1, n_split_grid=20,
#                        name='MoGLMTreeBoostClassifier', nn_max_epochs=10,
#                        reg_lambda=0.1, simplified=True, split_custom=None)

# %%
ts_neut_mono = TestSuite(ds, model_neut_mono) # store bundle of dataset and model in fs
# View model performance metrics
result = ts_neut_mono.diagnose_accuracy_table()
# display the output
result.table
# Out:
#           AUC     ACC      F1  LogLoss   Brier
# train  0.9141  0.8735  0.6579   0.3125  0.0940
# test   0.9153  0.8760  0.6667   0.3147  0.0932
# GAP    0.0012  0.0025  0.0088   0.0022 -0.0008

# %%
result = ts_neut_mono.interpret_effects(features="score")
result.plot()
# Out:
#             <!DOCTYPE html>
#             <html lang="en" style="height: 100%">
#             <head>
#             <meta charset="utf-8">
#             </head>
#             <body style="height: 100%; margin: 0">
#
#
#                 <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/echarts/5.5.0/echarts.min.js"></script>
#                 <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/echarts-gl/2.0.8/echarts-gl.min.js"></script>
#                 <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/dat-gui/0.7.9/dat.gui.min.js"></script>
#                 <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/echarts-wordcloud@2.1.0/dist/echarts-wordcloud.min.js"></script>
#
#             <div id="1751573416.77779460.8623" style="height: 600px; width: 600px; overflow: auto"></div>
#
#             <script type="text/javascript">
#             var dom = document.getElementById('1751573416.77779460.8623');
#             dom.innerHTML = ""
#             dom.setAttribute('_echarts_instance_', '')
#             var myChart = echarts.init(dom, null, {
#                 renderer: 'canvas',
#                 useDirtyRect: false
#                 });
#             var app = {};
#
#             var option;
#     option = {"chart_id": "1751573416.77779460.8623", "link_id": null, "figname": "", "title": {"show": true, "text": "score (13.0 %)", "link": "", "target": "blank", "textStyle": {"fontStyle": "normal", "fontWeight": "bolder", "fontFamily": "sans-serif", "fontSize": 15, "textBorderType": "solid", "textShadowColor": "transparent", "overflow": "none", "ellipsis": "..."}, "subtext": "", "sublink": "", "subtarget": "blank", "textAlign": "center", "textVerticalAlign": "auto", "padding": 0, "itemGap": 10, "z": 2, "left": "50.0%", "top": "5%", "right": "auto", "bottom": "auto", "backgroundColor": "transparent", "borderColor": "#ccc", "changed_name_key": {"id_": "id"}}, "grid": {"show": true, "width": "auto", "height": "auto", "z": 2, "left": "5%", "top": "10%", "right": "10%", "bottom": "5%", "borderColor": "#ccc", "borderWidth": 1, "containLabel": true, "backgroundColor": "transparent", "changed_name_key": {"id_": "id"}}, "legend": null, "brush": null, "yAxis": [{"show": true, "data": [0.6315790042830999, 0.6315790040278442, 0.6315790037851127, 0.6315790035549055, 0.6315790033372222, 0.6315790031320628, 0.631579002939428, 0.6315790027593172, 0.6315790025917302, 0.6315790024366675, 0.631579002294129, 0.6315790021641143, 0.6315790020471754, 0.6315790019448234, 0.6315790018571447, 0.6315790017841394, 0.6315790017258074, 0.631579001682149, 0.6315790016531642, 0.6315790016388527, 0.6315790016392147, 0.6315790016542501, 0.631579001683959, 0.6315790017283412, 0.6315790017873972, 0.6315790018611265, 0.6315790019495291, 0.6315790020526053, 0.6315790021703549, 0.631579002302778, 0.6315790024498746, 0.6315790026100994, 0.6315790027638158, 0.631579002905067, 0.6315790030338528, 0.6315790031501735, 0.6315790032540288, 0.6315790033454192, 0.6315790034243441, 0.6315790034908038, 0.6315790035447981, 0.6315790035863276, 0.6315790036153917, 0.6315790036319904, 0.6315790036361241, 0.6315790036277922, 0.6315790036069953, 0.6315790035737332, 0.631579003528006, 0.6315790034698132, 0.6315790033991554, 0.6315790033261081, 0.631579003262501, 0.6315790032083534, 0.6315790031636648, 0.6315790031284355, 0.6315790031026655, 0.6315790030863548, 0.6315790030795034, 0.6315790030821109, 0.6315790030941778, 0.631579003115704, 0.6315790031466897, 0.6315790031871341, 0.6315790032370382, 0.6315790032964013, 0.6315790033652235, 0.6315790034435054, 0.631579003531246, 0.6315790036284462, 0.6315790037340109, 0.631579003843101, 0.6315790039551422, 0.6315790040701348, 0.6315790041880786, 0.6315790043089734, 0.6315790044328194, 0.6315790045596168, 0.6315790046893652, 0.631579004822065, 0.6315790049577161, 0.6315790050963183, 0.6315790052378716, 0.6315790053823761, 0.6315790055298318, 0.631579005680239, 0.6315790058335969, 0.6315790059899064, 0.631579006149167, 0.6315790063117241, 0.6315790064888496, 0.6315790066859854, 0.6315790069031314, 0.6315790071402879, 0.6315790073974548, 0.6315790076746317, 0.6315790079718193, 0.6315790082890171, 0.6315790086262254, 0.6315790089834441, 0.6315790093606728, 0.6315790097579119, 0.6315790101751614, 0.6315790106124213, 0.6315790110696917, 0.6315790115469723, 0.6315790120442631, 0.6315790125615645, 0.631579013098876, 0.6315790136418118, 0.631579014162897, 0.6315790146614617, 0.6315790151375051, 0.6315790155910282, 0.6315790160220306, 0.6315790164305122, 0.6315790168164731, 0.6315790171799133, 0.6315790175208327, 0.6315790178392316, 0.6315790181351097, 0.6315790184084671, 0.6315790186593039, 0.6315790188876198, 0.631579019093415, 0.6315790192766895, 0.6315790194374434, 0.6315790195756764, 0.6315236185996214, 0.6309925947129911, 0.6298989021297101, 0.6282425408497785, 0.6260235108731964, 0.6232418121999636, 0.6198974448300801, 0.6159904087635462, 0.6115207040003616, 0.6064883305405266, 0.6008932883840408, 0.5947355775309043, 0.5880151979811175, 0.58073214973468, 0.5728864327915918, 0.5644780471518529, 0.5555069928154638, 0.5459732697824238, 0.5358768780527334, 0.5252080289928555, 0.5113700286105399, 0.492338980346133, 0.46811488419963415, 0.4 ...

# %%
tsc = TestSuite(ds, models=[model_gblt, model_neut, model_neut_mono])
results = tsc.compare_accuracy_table()
results.table
# Out:
#          GBLT                                 NeuralTree                  \
#           AUC     ACC      F1 LogLoss   Brier        AUC     ACC      F1
# train  0.9153  0.8742  0.6597  0.3113  0.0936     0.9156  0.8738  0.6558
# test   0.9169  0.8755  0.6631  0.3130  0.0926     0.9170  0.8765  0.6639
# GAP    0.0016  0.0012  0.0034  0.0017 -0.0009     0.0014  0.0027  0.0082
#
#                       NeuralTree-mono
#       LogLoss   Brier             AUC     ACC      F1 LogLoss   Brier
# train  0.3108  0.0935          0.9141  0.8735  0.6579  0.3125  0.0940
# test   0.3129  0.0926          0.9153  0.8760  0.6667  0.3147  0.0932
# GAP    0.0021 -0.0008          0.0012  0.0025  0.0088  0.0022 -0.0008

# %%
tsc = TestSuite(ds, models=[model_gblt, model_neut, model_neut_mono])
results = tsc.compare_residual_cluster(dataset="test")
results.plot("cluster_performance")
# Out:
#             <!DOCTYPE html>
#             <html lang="en" style="height: 100%">
#             <head>
#             <meta charset="utf-8">
#             </head>
#             <body style="height: 100%; margin: 0">
#
#
#                 <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/echarts/5.5.0/echarts.min.js"></script>
#                 <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/echarts-gl/2.0.8/echarts-gl.min.js"></script>
#                 <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/dat-gui/0.7.9/dat.gui.min.js"></script>
#                 <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/echarts-wordcloud@2.1.0/dist/echarts-wordcloud.min.js"></script>
#
#             <div id="1751573457.1706910.9687" style="height: 600px; width: 600px; overflow: auto"></div>
#
#             <script type="text/javascript">
#             var dom = document.getElementById('1751573457.1706910.9687');
#             dom.innerHTML = ""
#             dom.setAttribute('_echarts_instance_', '')
#             var myChart = echarts.init(dom, null, {
#                 renderer: 'canvas',
#                 useDirtyRect: false
#                 });
#             var app = {};
#
#             var option;
#     option = {"chart_id": "1751573457.1706910.9687", "link_id": null, "figname": "", "title": {"show": true, "text": "Cluster Performance", "link": "", "target": "blank", "textStyle": {"fontStyle": "normal", "fontWeight": "bolder", "fontFamily": "sans-serif", "fontSize": 15, "textBorderType": "solid", "textShadowColor": "transparent", "overflow": "none", "ellipsis": "..."}, "subtext": "", "sublink": "", "subtarget": "blank", "textAlign": "center", "textVerticalAlign": "auto", "padding": 0, "itemGap": 10, "z": 2, "left": "47.5%", "top": "5%", "right": "auto", "bottom": "auto", "backgroundColor": "transparent", "borderColor": "#ccc", "changed_name_key": {"id_": "id"}}, "grid": [{"top": "10%", "bottom": "38.0%", "left": "10%", "right": "20%", "show": true, "width": "auto", "height": "auto", "containLabel": false}, {"top": "66.0%", "bottom": "10%", "left": "10%", "right": "20%", "show": true, "width": "auto", "height": "auto", "containLabel": false}], "legend": {"show": true, "type": "plain", "width": "auto", "height": "auto", "orient": "vertical", "align": "auto", "itemWidth": 25, "itemHeight": 14, "symbolRotate": "inherit", "selectedMode": true, "padding": 5, "itemGap": 10, "z": 4, "left": "auto", "top": "10%", "right": "1%", "bottom": "auto", "borderColor": "#ccc", "borderWidth": 1, "inactiveColor": "#ccc", "inactiveBorderColor": "#ccc", "inactiveBorderWidth": "auto", "selected": {}, "textStyle": {"overflow": "truncate", "fontSize": 12, "color": "#747475"}, "pageButtonItemGap": 5, "pageButtonPosition": "end", "pageFormatter": "{current}/{total}", "pageIconColor": "#2f4554", "pageIconInactiveColor": "#aaa", "pageIconSize": 15, "animationDurationUpdate": 800, "selectorItemGap": 7, "selectorButtonGap": 10}, "brush": null, "yAxis": [{"show": true, "type": "value", "position": "bottom", "name": "AUC", "nameLocation": "center", "nameTextStyle": {"color": "#747475", "fontStyle": "normal", "fontWeight": "normal", "fontFamily": "sans-serif", "fontSize": 12, "backgroundColor": "", "borderType": "solid", "shadowColor": "transparent", "textBorderType": "solid", "textShadowColor": "transparent", "overflow": "none", "ellipsis": "..."}, "nameGap": "auto", "min": -0.1, "max": 1.1, "splitNumber": 5, "logBase": 10, "axisLine": {}, "axisTick": {"show": true, "alignWithLabel": "none", "interval": "auto", "length": 5}, "axisLabel": {"show": true, "margin": 8, "showMinLabel": false, "showMaxLabel": false, "fontStyle": "normal", "fontWeight": "normal", "fontFamily": "sans-serif", "fontSize": 12, "backgroundColor": "transparent", "borderType": "solid", "shadowColor": "transparent", "textBorderType": "solid", "textShadowColor": "transparent", "overflow": "none", "ellipsis": "...", "width": 30.0}, "splitLine": {"show": true, "interval": "auto"}, "splitArea": {"show": false, "interval": "auto"}, "axisPointer": {"show": false}, "dimension": "2d", "gridIndex": 0, "ignored": false, "changed_name_key": {"min_": "min", "max_": "max", "type_": "type", "name_": "name"}}, {"show": true, "type": "value", "position": "bottom", "name": "Size", "nameLocation": "center", "nameTextStyle": {"color": "#747475", "fontStyle": "normal", "fontWeight": "normal", "fontFamily": "sans-serif", "fontSize": 12, "backgroundColor": "", "borderType": "solid", "shadowColor": "transparent", "textBorderType": "solid", "textShadowColor": "transparent", "overflow": "none", "ellipsis": "..."}, "nameGap": "auto", "min": -56.0, "max": 614.0, "splitNumber": 5, "logBase": 10, "axisLine": {}, "axisTick": {"show": true, "alignWithLabel": "none", "interval": "auto", "length": 5}, "axisLabel": {"show": true, "margin": 8, "showMinLabel": false, "showMaxLabel": false, "fontStyle": "normal", "fontWeight": "normal", "fontFamily": "sans-serif", "fontSize": 12, "backgroundColor": "transparent", "borderType": "solid", "shadowColor": "transparent", "textBorderType": "solid", "textShadowColor": "transparent", "overflow": "none", "ellipsis": "...", "width": 30.0}, "splitLine": {"show": true, "interval": "au ...
